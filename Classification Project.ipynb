# %% [markdown]
# ## <b>Data Science - Binary Disorder</b>
#
#
# ### <b>Confusion matrix of binary classification.</b>
#
# For binary classifications, a confusion matrix is a two-by-two matrix to visualize the performance of an algorithm. Each row of the matrix represents the instances in a predicted class while each column represents the instances in an actual class.
#
# ### <b>Task</b>
# Given two lists of 1s and 0s (1 represents the true label, and 0 represents the false false) of the same length, output a 2darrary of counts, each cell is defined as follows
#
# <p>Top left: Predicted true and actually true (True positive)</p>
# <p>Top right: Predicted true but actually false (False positive)</p>
# <p>Bottom left: Predicted false but actually true (False negative)</p>
# <p>Bottom right: Predicted false and actually false (True negative)</p>
#
# ### <b>Input Format</b>
# First line: a list of 1s and 0s, separated by space. They are the actual binary labels.
# <p>Second line: a list of 1s and 0s, the length is the same as the first line. They represented the predicted labels.</p>
#
# ### <b>Output Format</b>
# A numpy 2darray of two rows and two columns, the first row contains counts of true positives and false positives and the second row contains counts of false negatives and true negatives.
#
# ### Sample Input
# <p>1 1 0 0</p>
# <p>1 0 0 0</p>
#
#
# ### Sample Output
# <p>[[1., 0.],</p>
# <p>[1., 2.]]</p>
#
# <hr>
#
# <p>Explanation</p>
#
# Among the actual labels, there are 2 trues and 2 falses. One true label was correctly predicted as true and the other was incorrectly predicted as false; that is, one true positive and one false negative. Of the two false labels, both were correctly predicted; that is, zero false positive and two true negatives.

# %% [markdown]
# # <B>SOLUTION 1</B>
# ##  THIS IS A TEST, THIS CODE IS UNNECESARILY LONG, TRYING TO IRON OUT THE LOGIC

# %%
import numpy as np

y_true = [int(x) for x in input().split()]
y_pred =  [int(x) for x in input().split()]

truePositive = []
falsePositive = []
falseNegative = []
trueNegative = []


if (y_true[0] and y_pred[0]) ==1 :
    truePositive.append(1)
    print(truePositive)
if (y_true[0]==0) and (y_pred[0]==1):
    falsePositive.append(1)
    print(falsePositive)
if (y_true[0]==1) and (y_pred[0]==0):
    falseNegative.append(1)
    print(falseNegative)
if (y_true[0]==0) and (y_pred[0]==0):
    trueNegative.append(1)
    print(trueNegative)

    # NEXT INDEX

if (y_true[1] and y_pred[1]) ==1 :
    truePositive.append(1)
    print(truePositive)
if (y_true[1]==0) and (y_pred[1]==1):
    falsePositive.append(1)
    print(falsePositive)
if (y_true[1]==1) and (y_pred[1]==0):
    falseNegative.append(1)
    print(falseNegative)
if (y_true[1]==0) and (y_pred[1]==0):
    trueNegative.append(1)
    print(trueNegative)

    # NEXT INDEX 

if (y_true[2]==1) and (y_pred[2]==1) :
    truePositive.append(1)
    print(truePositive)
if (y_true[2]==0) and (y_pred[2]==1):
    falsePositive.append(1)
    print(falsePositive)
if (y_true[2]==1) and (y_pred[2]==0):
    falseNegative.append(1)
    print(falseNegative)
if (y_true[2]==0) and (y_pred[2]==0):
    trueNegative.append(1)
    print(trueNegative)

    # NEXT INDEX 

if (y_true[3]==1) and (y_pred[3] ==1) :
    truePositive.append(1)
    print(truePositive)
if (y_true[3]==0) and (y_pred[3]==1):
    falsePositive.append(1)
    print(falsePositive)
if (y_true[3]==1) and (y_pred[3]==0):
    falseNegative.append(1)
    print(falseNegative)
if (y_true[3]==0) and (y_pred[3]==0):
    trueNegative.append(1)
    print(trueNegative)


array1 = np.array([[len(truePositive),len(falsePositive)],[len(falseNegative), len(trueNegative)]])

print(f'y_true = {y_true} \n y_pred = {y_pred} \n True positives = {truePositive} \n False positives = {falsePositive} \n False Negatives = {falseNegative}, \n True Negatives = {trueNegative} \n final array = {array1}')
# Out:
# [1]
# [1]
# [1]
# [1, 1]
# y_true = [1, 1, 0, 0]
#  y_pred = [1, 0, 0, 0]
#  True positives = [1]
#  False positives = []
#  False Negatives = [1],
#  True Negatives = [1, 1]
#  final array = [[1 0]
#  [1 2]]

# %% [markdown]
# # <b>CORRECT SOLUTION</b> - SIMPLE IS BETTER

# %%
### EXAMPLE 2

import numpy as np

y_true = [int(x) for x in input().split()]
y_pred =  [int(x) for x in input().split()]


# initializes the lists of different conditions
truePositive = []
falsePositive = []
falseNegative = []
trueNegative = []

# Initiates i as 0
i=0 

# loop runs the number of times as the number of elements in the lists
for j in y_true:
    if (y_true[i]==1) and (y_pred[i] ==1) :
        truePositive.append(1)

    if (y_true[i]==0) and (y_pred[i]==1):
        falsePositive.append(1)
        
    if (y_true[i]==1) and (y_pred[i]==0):
        falseNegative.append(1)

    if (y_true[i]==0) and (y_pred[i]==0):
        trueNegative.append(1)

    # i increases with each loop to get the element in the next index    
    i+=1


# converts all the lists to a two dimensional array in the right order
array1 = np.array([[len(truePositive),len(falsePositive)],[len(falseNegative), len(trueNegative)]])


# summary of the loop
print(f'y_true = {y_true} \n y_pred = {y_pred} \n True positives = {truePositive} \n False positives = {falsePositive} \n False Negatives = {falseNegative}, \n True Negatives = {trueNegative} \n final array = {array1}')
# Out:
# y_true = [1, 1, 0, 0]
#  y_pred = [1, 0, 0, 0]
#  True positives = [1]
#  False positives = []
#  False Negatives = [1],
#  True Negatives = [1, 1]
#  final array = [[1 0]
#  [1 2]]
